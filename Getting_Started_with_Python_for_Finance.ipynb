# %% [markdown]
# <a href="https://colab.research.google.com/github/MassGH2023/Python-Coding-Practice/blob/main/Getting_Started_with_Python_for_Finance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import dates
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import yfinance as yf

# %%
raw = yf.download('SPY NVDA', start = '2020-01-01')
# Out:
# /tmp/ipython-input-2354081889.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   raw = yf.download('SPY NVDA', start = '2020-01-01')
# [*********************100%***********************]  2 of 2 completed

# %%
raw
# Out:
# Price            Close                    High                     Low  \
# Ticker            NVDA         SPY        NVDA         SPY        NVDA
# Date
# 2020-01-02    5.971747  299.406433    5.971747  299.424883    5.892343
# 2020-01-03    5.876163  297.139221    5.919973  298.272823    5.827127
# 2020-01-06    5.900805  298.272888    5.906033  298.355831    5.756683
# 2020-01-07    5.972245  297.434174    6.018045  298.180683    5.884128
# 2020-01-08    5.983446  299.019379    6.024766  300.245120    5.927937
# ...                ...         ...         ...         ...         ...
# 2025-08-11  182.059998  635.919983  183.839996  638.950012  180.250000
# 2025-08-12  183.160004  642.690002  184.479996  642.849976  179.460007
# 2025-08-13  181.589996  644.890015  183.970001  646.190002  179.350006
# 2025-08-14  182.020004  644.950012  183.020004  645.619995  179.460007
# 2025-08-15  180.449997  643.440002  181.899994  646.090027  178.039993
#
# ...

# %%
import datetime
today = datetime.date.today()
today = today.strftime("%Y-%m-%d")
today
# Out:
# '2025-08-16'

# %%
type(raw)
# Out:
# pandas.core.frame.DataFrame

# %%
raw.columns
# Out:
# MultiIndex([( 'Close', 'NVDA'),
#             ( 'Close',  'SPY'),
#             (  'High', 'NVDA'),
#             (  'High',  'SPY'),
#             (   'Low', 'NVDA'),
#             (   'Low',  'SPY'),
#             (  'Open', 'NVDA'),
#             (  'Open',  'SPY'),
#             ('Volume', 'NVDA'),
#             ('Volume',  'SPY')],
#            names=['Price', 'Ticker'])

# %%
raw.pipe?

# %%
raw.columns = [col[0] for col in raw.columns]

# %%
def fix_cols(df):

  columns = df.columns
  outer = [col[0] for col in columns]
  df.columns = outer
  return df

# %%
(raw.iloc[:,::2].pipe(fix_cols))
# Out:
#                  Close        High         Low        Open     Volume
# Date
# 2020-01-02    5.971747    5.971747    5.892343    5.942873  237536000
# 2020-01-03    5.876163    5.919973    5.827127    5.852019  205384000
# 2020-01-06    5.900805    5.906033    5.756683    5.782819  262636000
# 2020-01-07    5.972245    6.018045    5.884128    5.929182  314856000
# 2020-01-08    5.983446    6.024766    5.927937    5.968013  277108000
# ...                ...         ...         ...         ...        ...
# 2025-08-11  182.059998  183.839996  180.250000  182.050003  138323200
# 2025-08-12  183.160004  184.479996  179.460007  182.960007  145485700
# 2025-08-13  181.589996  183.970001  179.350006  182.619995  179871700
# 2025-08-14  182.020004  183.020004  179.460007  179.750000  129554000
# 2025-08-15  180.449997  181.899994  178.039993  181.880005  156254400
#
# [1413 rows x 5 columns]

# %%
raw
# Out:
# Price            Close                    High                     Low  \
# Ticker            NVDA         SPY        NVDA         SPY        NVDA
# Date
# 2020-01-02    5.971747  299.406433    5.971747  299.424883    5.892343
# 2020-01-03    5.876163  297.139221    5.919973  298.272823    5.827127
# 2020-01-06    5.900805  298.272888    5.906033  298.355831    5.756683
# 2020-01-07    5.972245  297.434174    6.018045  298.180683    5.884128
# 2020-01-08    5.983446  299.019379    6.024766  300.245120    5.927937
# ...                ...         ...         ...         ...         ...
# 2025-08-11  182.059998  635.919983  183.839996  638.950012  180.250000
# 2025-08-12  183.160004  642.690002  184.479996  642.849976  179.460007
# 2025-08-13  181.589996  644.890015  183.970001  646.190002  179.350006
# 2025-08-14  182.020004  644.950012  183.020004  645.619995  179.460007
# 2025-08-15  180.449997  643.440002  181.899994  646.090027  178.039993
#
# ...

# %%
raw.columns
# Out:
# MultiIndex([( 'Close', 'NVDA'),
#             ( 'Close',  'SPY'),
#             (  'High', 'NVDA'),
#             (  'High',  'SPY'),
#             (   'Low', 'NVDA'),
#             (   'Low',  'SPY'),
#             (  'Open', 'NVDA'),
#             (  'Open',  'SPY'),
#             ('Volume', 'NVDA'),
#             ('Volume',  'SPY')],
#            names=['Price', 'Ticker'])

# %%
def tweak_data():

  raw = yf.download("SPY NVDA", start = '2020-01-01')
  return (raw.iloc[:,::2].pipe(fix_cols))

# %%
raw.iloc[:, ::2].columns
# Out:
# MultiIndex([( 'Close', 'NVDA'),
#             (  'High', 'NVDA'),
#             (   'Low', 'NVDA'),
#             (  'Open', 'NVDA'),
#             ('Volume', 'NVDA')],
#            names=['Price', 'Ticker'])

# %%
tweak_data()
# Out:
# /tmp/ipython-input-204183772.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   raw = yf.download("SPY NVDA", start = '2020-01-01')
# [*********************100%***********************]  2 of 2 completed
#                  Close        High         Low        Open     Volume
# Date
# 2020-01-02    5.971747    5.971747    5.892344    5.942873  237536000
# 2020-01-03    5.876163    5.919972    5.827126    5.852018  205384000
# 2020-01-06    5.900806    5.906034    5.756684    5.782820  262636000
# 2020-01-07    5.972245    6.018045    5.884128    5.929182  314856000
# 2020-01-08    5.983446    6.024766    5.927938    5.968013  277108000
# ...                ...         ...         ...         ...        ...
# 2025-08-11  182.059998  183.839996  180.250000  182.050003  138323200
# 2025-08-12  183.160004  184.479996  179.460007  182.960007  145485700
# 2025-08-13  181.589996  183.970001  179.350006  182.619995  179871700
# ...

# %%
raw.iloc[:,:-2:2].pipe(fix_cols)
# Out:
#                  Close        High         Low        Open
# Date
# 2020-01-02    5.971747    5.971747    5.892343    5.942873
# 2020-01-03    5.876163    5.919973    5.827127    5.852019
# 2020-01-06    5.900805    5.906033    5.756683    5.782819
# 2020-01-07    5.972245    6.018045    5.884128    5.929182
# 2020-01-08    5.983446    6.024766    5.927937    5.968013
# ...                ...         ...         ...         ...
# 2025-08-11  182.059998  183.839996  180.250000  182.050003
# 2025-08-12  183.160004  184.479996  179.460007  182.960007
# 2025-08-13  181.589996  183.970001  179.350006  182.619995
# 2025-08-14  182.020004  183.020004  179.460007  179.750000
# 2025-08-15  180.449997  181.899994  178.039993  181.880005
#
# [1413 rows x 4 columns]

# %%
raw.iloc[:,:-2:2].pipe(fix_cols).plot()
# Out:
# <Axes: xlabel='Date'>

# %%
raw.iloc[:,:-2:2].pipe(fix_cols).Close.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
raw.iloc[:,::2].pipe(fix_cols).Volume.plot(figsize = (20,3))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# # resampling
